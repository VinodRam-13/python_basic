# %% [markdown]
# **Mutable Objects**
#
#
# *   Mutable data type can be edited (modify) i.e. they can change at runtime
# *   example : List, Dictionary..etc

# %%
food = ['Rice', 'Banana', 'Beans']
food.append("Chappathi")
print(food)

# %% [markdown]
# **Immutable Objects**
#
# *   Immutable Data type can not be edited (modify)i.e. they can be change at runtime
# *   Example: string, tuples..etc

# %%
Food_shop = "Chinese Food"
print(Food_shop)
Food_shop(3) = e
print(Food_shop)
/it will throw an error

# %%
Food_shop1 = "Chinese Food"
print(Food_shop1)
Food_shop2 = Food_shop1.upper()
print(Food_shop2)
